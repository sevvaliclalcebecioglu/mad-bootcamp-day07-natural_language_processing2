# %%
import joblib

# %%
model=joblib.load('rf_hsc.pkl')

# %%
text=['Hello how are you, is everything alright']

# %%
text2=['free entry wkly comp win fa cup final tkts']

# %%
model.predict(text)[0]
# Out:
# np.int64(0)

# %%
model.predict(text2)[0]
# Out:
# np.int64(1)
