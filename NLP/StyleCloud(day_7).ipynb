# %% [markdown]
# # _Style Cloud_

# %% [markdown]
# _Bu projede, verilen metinlerden kelime frekanslarına dayalı kelime bulutları oluşturmak, farklı ikon ve görsel maskeleri kullanarak özelleştirilmiş bulut görüntüleri üretmek ve ek olarak metinlerin duygu analizini yapmak amaçlanmıştır. Python kütüphaneleri olan WordCloud, stylecloud, TextBlob, transformers, matplotlib ve joblib kullanılarak veri işleme, model yükleme, model tahmini ve görselleştirme işlemleri gerçekleştirilmiştir._

# %%
#pip install stylecloud

# %%
# stylecloud kütüphanesini yüklemek için gerekli pip komutu

# %%
#!pip install Pillow==9.5.0

# %%
# pillow kütüphanesinin 9.5.0 sürümünü yüklemek için pip komutu

# %%
import stylecloud as sc

# stylecloud kütüphanesini sc takma adıyla projeye dahil eder

# %%
import matplotlib.pyplot as plt

# matplotlib ile grafik işlemleri yapmak için pyplot modülünü dahil eder

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch1.png')

# challenge.txt dosyasındaki kelimelerden bir stylecloud oluşturup ch1.png olarak kaydeder

# %%
from IPython.display import Image
# Görsellerin notebook içinde görüntülenmesi için Image sınıfını içe aktarır

Image(filename='ch1.png')
# ch1.png görselini notebook içinde gösterir

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-car', output_name='ch2.png')

# challenge.txt metniyle araba simgesi şeklinde stylecloud oluşturur ve ch2.png olarak kaydeder

# %%
from IPython.display import Image
# Notebook içinde görsel göstermek için Image sınıfını içe aktarır

Image(filename='ch2.png')
# ch2.png görselini notebook'ta görüntüler

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-cloud', output_name='ch3.png')

# challenge.txt metniyle bulut şekilli stylecloud oluşturur ve ch3.png olarak kaydeder

# %%
from IPython.display import Image
# Notebook ortamında görselleri görüntülemek için Image sınıfını içe aktarır

Image(filename='ch3.png')
# ch3.png görselini notebook içinde gösterir

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-star-and-crescent', output_name='ch4.png', background_color='red', colors='white')

# challenge.txt metniyle ay-yıldız ikonlu bir stylecloud oluşturur, arka planı kırmızı ve kelimeleri beyaz yaparak ch4.png olarak kaydeder

# %%
from IPython.display import Image
# Görselleri notebook içinde göstermek için Image sınıfını içe aktarır

Image(filename='ch4.png')
# ch4.png dosyasını notebook içinde ekranda gösterir

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-fighter-jet', output_name='ch5.png', background_color='black', colors=('white','yellow'))

# challenge.txt metniyle jet ikonlu stylecloud üretir, siyah arka plan ve beyaz/sarı kelimelerle ch5.png olarak kaydeder

# %%
from IPython.display import Image
# Jupyter ortamında görselleri göstermek için Image sınıfını içe aktarır

Image(filename='ch5.png')
# ch5.png görselini notebook'ta görüntüler

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-heart', output_name='ch6.png', background_color='white', colors=('maroon','red'))

# challenge.txt dosyasından kalp ikonlu stylecloud oluşturur, beyaz arka plan ve bordo/kırmızı renkte metinlerle ch6.png olarak kaydeder

# %%
from IPython.display import Image
# Notebook ortamında görsel göstermek için Image sınıfını içe aktarır

Image(filename='ch6.png')
# ch6.png dosyasını görüntüler
