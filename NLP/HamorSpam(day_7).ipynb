# %% [markdown]
# # _Natural Language Processing 2_

# %% [markdown]
# ### _Text Cleaning and Preprocessing with NeatText_

# %%
import neattext as nfx  

# neattext kütüphanesini içe aktarır; metin temizleme ve ön işleme işlemleri için kullanılır

# %%
s = open('test_document.txt', 'r', encoding='utf-8').read()  

# 'test_document.txt' dosyasını okuyup tüm içeriği tek bir string olarak alır

# %%
s  

# Dosyanın içeriğini ekrana veya değişkene basar; metni görüntüler
# Out:
# '\nDear User! 😊🎉\n\nWe are <b>excited</b> to inform you that your registration is complete! 🔥🔥🔥\nEncounter issues❓ Contact: support@example.com 👍\n\nFor marketing, inquiries📢 reach out: marketing@sample.org or sales-team@business123.com💼\n\n‼️ PLEASE NOTE: Do not reply to no-reply@mailer.system.net 📵 (Unmonitored)\n\nForgot your password❓❗️ Email: password.reset@securemail.co.uk 🔐\n\nThank you 🙏 for your cooperation!\n\nBest Regards,\nAdmin Team 🖥️\nadmin.team@mywebsite.com\n\n## User Feedback 💡\n\nWe value your feedback! Share your experiences 🌟 at feedback@customer-reviews.io 📧\n\nTechnical assistance: email tech-support@techsolutions.net or 📞 our helpline.\n\n### Random User Information 📝:\n\n- John Doe: john.doe123@examplemail.com 🧑\u200d💻\n- Jane Smith: jane.smith987@randommail.org 👩\u200d🔬\n- Alice Brown: alice_brown@abc-company.co 👩\u200d💼\n\n### Internal Contacts 📂:\n\n- CEO Office 🏢: ceo.office@company-exec.com\n- HR Department 🧑\u200d🤝\u200d🧑: hr.department@corporate-group.
# ...

# %%
nfx.extract_emails(s)  

# Metin içindeki tüm e-posta adreslerini çıkarır ve liste halinde döndürür
# Out:
# ['support@example.com',
#  'marketing@sample.org',
#  'sales-team@business123.com',
#  'no-reply@mailer.system.net',
#  'password.reset@securemail.co.uk',
#  'admin.team@mywebsite.com',
#  'feedback@customer-reviews.io',
#  'tech-support@techsolutions.net',
#  'john.doe123@examplemail.com',
#  'jane.smith987@randommail.org',
#  'alice_brown@abc-company.co',
#  'ceo.office@company-exec.com',
#  'hr.department@corporate-group.com',
#  'it_helpdesk@it-support.biz',
#  'info@canada-office.ca',
#  'support.au@serviceprovider.com.au',
#  'kontakt@firma-beispiel.de',
#  'serviceclient@exemple.fr',
#  '技術サポート@例え.jp',
#  'informacion@empresa.es',
#  'vendas@empresa.com.br',
#  'запросы@пример.рф',
#  '咨询@公司.cn',
#  'seva@bharat.co.in']

# %%
s = nfx.remove_emails(s)  

# Metindeki tüm e-posta adreslerini kaldırır

# %%
s  

# E-posta adresleri temizlendikten sonra metnin güncellenmiş hâlini görüntüler
# Out:
# '\nDear User! 😊🎉\n\nWe are <b>excited</b> to inform you that your registration is complete! 🔥🔥🔥\nEncounter issues❓ Contact:  👍\n\nFor marketing, inquiries📢 reach out:  or 💼\n\n‼️ PLEASE NOTE: Do not reply to  📵 (Unmonitored)\n\nForgot your password❓❗️ Email:  🔐\n\nThank you 🙏 for your cooperation!\n\nBest Regards,\nAdmin Team 🖥️\n\n\n## User Feedback 💡\n\nWe value your feedback! Share your experiences 🌟 at  📧\n\nTechnical assistance: email  or 📞 our helpline.\n\n### Random User Information 📝:\n\n- John Doe:  🧑\u200d💻\n- Jane Smith:  👩\u200d🔬\n- Alice Brown:  👩\u200d💼\n\n### Internal Contacts 📂:\n\n- CEO Office 🏢: \n- HR Department 🧑\u200d🤝\u200d🧑: \n- IT Helpdesk 🛠️: \n\n### International Contacts 🌐:\n\n- Canada Office 🍁: \n- Australia Support 🇦🇺: \n- Germany Team 🇩🇪: \n- France Customer Service 🇫🇷: \n- Japan Technical Support 🇯🇵: \n- Spain Info 🇪🇸: \n- Brazil Sales 🇧🇷: \n- Russia Queries 🇷🇺: \n- China Inquiries 🇨🇳: \n- India Services 🇮🇳: \n\nSome random HTML code:\n<div class="foote
# ...

# %%
s = nfx.remove_emojis(s)  

# Metindeki tüm emoji karakterlerini kaldırır

# %%
s  

# Emojiler temizlendikten sonra metnin güncellenmiş hâlini görüntüler
# Out:
# '\nDear User! \n\nWe are <b>excited</b> to inform you that your registration is complete! \nEncounter issues Contact:  \n\nFor marketing, inquiries reach out:  or \n\n‼ PLEASE NOTE: Do not reply to   (Unmonitored)\n\nForgot your password Email:  \n\nThank you  for your cooperation!\n\nBest Regards,\nAdmin Team \n\n\n## User Feedback \n\nWe value your feedback! Share your experiences  at  \n\nTechnical assistance: email  or  our helpline.\n\n### Random User Information :\n\n- John Doe:  🧑\u200d\n- Jane Smith:  \u200d\n- Alice Brown:  \u200d\n\n### Internal Contacts :\n\n- CEO Office : \n- HR Department 🧑\u200d🤝\u200d🧑: \n- IT Helpdesk : \n\n### International Contacts :\n\n- Canada Office : \n- Australia Support : \n- Germany Team : \n- France Customer Service : \n- Japan Technical Support : \n- Spain Info : \n- Brazil Sales : \n- Russia Queries : \n- China Inquiries : \n- India Services : \n\nSome random HTML code:\n<div class="footer">©2025 <a href="https://example.com">Example Corp<
# ...

# %%
s = nfx.remove_special_characters(s)  

# Metindeki özel karakterleri temizler; yalnızca harf ve sayıları bırakır

# %%
s  

# Özel karakterler temizlendikten sonra metnin güncellenmiş hâlini görüntüler
# Out:
# 'Dear User We are bexcitedb to inform you that your registration is complete Encounter issues Contact  For marketing inquiries reach out  or  PLEASE NOTE Do not reply to   UnmonitoredForgot your password Email  Thank you  for your cooperationBest RegardsAdmin Team  User Feedback We value your feedback Share your experiences  at  Technical assistance email  or  our helpline Random User Information  John Doe   Jane Smith   Alice Brown   Internal Contacts  CEO Office   HR Department   IT Helpdesk   International Contacts  Canada Office   Australia Support   Germany Team   France Customer Service   Japan Technical Support   Spain Info   Brazil Sales   Russia Queries   China Inquiries   India Services  Some random HTML codediv classfooter2025 a hrefhttpsexamplecomExample Corpa All rights reserveddivscriptalertThis is a test alert script Historical Quotes  To be or not to be that is the question  William Shakespeare  I think therefore I am  Ren Descartes  Thats one small step for man one g
# ...

# %%
s = nfx.normalize(s)  

# Metni normalize eder: boşlukları düzeltir, gereksiz tekrarları kaldırır ve yazım standartlarını uygular

# %%
s  

# Normalize edildikten sonra metnin güncellenmiş hâlini görüntüler
# Out:
# 'dear user we are bexcitedb to inform you that your registration is complete encounter issues contact  for marketing inquiries reach out  or  please note do not reply to   unmonitoredforgot your password email  thank you  for your cooperationbest regardsadmin team  user feedback we value your feedback share your experiences  at  technical assistance email  or  our helpline random user information  john doe   jane smith   alice brown   internal contacts  ceo office   hr department   it helpdesk   international contacts  canada office   australia support   germany team   france customer service   japan technical support   spain info   brazil sales   russia queries   china inquiries   india services  some random html codediv  a hrefhttpsexamplecomexample corpa all rights reserveddivscriptalertthis is a test alert script historical quotes  to be or not to be that is the question  william shakespeare  i think therefore i am  ren descartes  thats one small step for man one giant leap for m
# ...

# %% [markdown]
# ### _Downloading NLTK Corpora (Gutenberg Dataset)_

# %%
import nltk  

# Doğal dil işleme (NLP) görevleri için NLTK kütüphanesini içe aktarır

# %%
nltk.download('gutenberg')  

# NLTK kütüphanesinin Gutenberg metin koleksiyonunu indirir
# Örnek metinleri analiz etmek ve NLP denemeleri yapmak için kullanılır
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\13tua\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()  

# Gutenberg koleksiyonunda bulunan metin dosyalarının isimlerini listeler
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
seyhpir = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')  

# Gutenberg koleksiyonundaki 'shakespeare-hamlet.txt' dosyasının tüm metnini ham string olarak alır

# %%
seyhpir  

# 'shakespeare-hamlet.txt' metninin tamamını ekrana veya değişkene basar
# Out:
# "[The Tragedie of Hamlet by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Barnardo and Francisco two Centinels.\n\n  Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe\n\n   Bar. Long liue the King\n\n   Fran. Barnardo?\n  Bar. He\n\n   Fran. You come most carefully vpon your houre\n\n   Bar. 'Tis now strook twelue, get thee to bed Francisco\n\n   Fran. For this releefe much thankes: 'Tis bitter cold,\nAnd I am sicke at heart\n\n   Barn. Haue you had quiet Guard?\n  Fran. Not a Mouse stirring\n\n   Barn. Well, goodnight. If you do meet Horatio and\nMarcellus, the Riuals of my Watch, bid them make hast.\nEnter Horatio and Marcellus.\n\n  Fran. I thinke I heare them. Stand: who's there?\n  Hor. Friends to this ground\n\n   Mar. And Leige-men to the Dane\n\n   Fran. Giue you good night\n\n   Mar. O farwel honest Soldier, who hath relieu'd you?\n  Fra. Barnardo ha's my place: giue you goodnight.\n\nExit Fran.\n\n  Mar. Holla Barnardo\n\n   Bar
# ...

# %%
seyhpir = nfx.TextFrame(seyhpir)  

# Hamlet metnini neattext’in TextFrame objesine dönüştürür; metin analizi ve istatistikleri için kullanılabilir

# %%
seyhpir.describe()  

# TextFrame içindeki Hamlet metni ile ilgili istatistikleri özetler; kelime sayısı, karakter sayısı gibi bilgiler verir
# Out:
# Key      Value
# Length  : 162881
# vowels  : 48344
# consonants: 73960
# stopwords: 13996
# punctuations: 7093
# special_char: 7093
# tokens(whitespace): 29605
# tokens(words): 30273

# %%
seyhpir.readability()  

# Hamlet metninin okunabilirlik skorunu hesaplar
# Örneğin Flesch Reading Ease veya benzeri metriklerle metnin zorluk seviyesini değerlendirir
# Out:
# {'automated readability': 12.990613823318782,
#  'description': '18-24 years (College student)'}

# %% [markdown]
# ### _SMS Spam Detection Using Natural Language Processing_

# %% [markdown]
# _Bugün bir GSM şirketine bir makine öğrenmesi modeli geliştireceğiz._ <br>
# _Gelen sms mesajlarının gerçek mi yoksa reklam mı olduğunu anlayan model._

# %% [markdown]
# #### _İmport - Eda_

# %%
import pandas as pd  

# Veri işleme ve DataFrame kullanımı için pandas kütüphanesini içe aktarır

# %%
df = pd.read_csv('spam.csv', encoding='iso-8859-1')  

# 'spam.csv' dosyasını pandas DataFrame olarak yükler; encoding belirtilerek karakter hatalarının önüne geçilir

# %%
df.head()  

# DataFrame’in ilk 5 satırını görüntüler; veri yapısını hızlıca görmek için kullanılır
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.info()  

# DataFrame’in sütun bilgilerini, veri tiplerini ve eksik değerleri özetler
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df = df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)  

# Gereksiz sütunları DataFrame’den kaldırır
# axis=1 -> sütun siler
# axis=0 -> satır siler

# %%
df.head()  

# Gereksiz sütunlar kaldırıldıktan sonra DataFrame’in ilk 5 satırını görüntüler
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns = ['class', 'text']  

# DataFrame sütunlarını yeniden adlandırır: 'class' ve 'text'

# %%
df.head()  

# Sütun isimleri güncellendikten sonra DataFrame’in ilk 5 satırını görüntüler
# Out:
#   class                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# #### _Text Cleaning and Preprocessing with NeatText_

# %% [markdown]
# _Metin verileri, makine öğrenmesi ve doğal dil işleme (NLP) projelerinde genellikle ham ve gürültülü bir yapıdadır. Bu nedenle modelleme aşamasından önce metinlerin temizlenmesi ve standart bir formata getirilmesi kritik bir adımdır. Bu çalışmada, SMS mesajları üzerinde NeatText kütüphanesi kullanılarak metin temizleme ve ön işleme adımları uygulanmıştır._

# %%
import neattext as nfx  

# Metin temizleme ve ön işleme işlemleri için neattext kütüphanesini içe aktarır

# %%
df['text'] = df['text'].apply(nfx.normalize)  

# DataFrame’deki tüm metinleri normalize eder; boşlukları düzeltir ve yazım standartlarını uygular

# %%
df['text'] = df['text'].apply(nfx.clean_text)  

# DataFrame’deki tüm metinleri temizler; özel karakterler, sayılar ve gereksiz boşlukları kaldırır

# %%
df['text'] = df['text'].apply(nfx.remove_special_characters)  

# DataFrame’deki metinlerden özel karakterleri kaldırır

# %%
df['text']  

# Temizlenmiş ve özel karakterlerden arındırılmış metin sütununu görüntüler
# Out:
# 0       jurong point crazy available bugis n great wor...
# 1                                 ok lar joking wif u oni
# 2       free entry wkly comp win fa cup final tkts  te...
# 3                                 u dun early hor u c say
# 4                                nah think goes usf lives
#                               ...
# 5567    time tried contact u u  pound prize claim easy...
# 5568                            b going esplanade fr home
# 5569                    pity  mood that soany suggestions
# 5570    guy bitching acted like id interested buying w...
# 5571                                            rofl true
# Name: text, Length: 5572, dtype: object

# %%
s = ' '.join(df['text'])  

# Tüm metinleri tek bir string hâline getirir; kelime frekans analizi ve görselleştirme için kullanılır

# %%
s  

# Birleştirilmiş ve temizlenmiş tüm metni görüntüler
# Out:
# 'jurong point crazy available bugis n great world la e buffet cine got amore wat ok lar joking wif u oni free entry wkly comp win fa cup final tkts  text fa receive entry questionstd txt ratetcs apply s u dun early hor u c say nah think goes usf lives freemsg hey darling weeks word back id like fun still tb ok xxx std chgs send  rcv brother like speak me treat like aids patent request melle melle oru minnaminunginte nurungu vettam set callertune callers press  copy friends callertune winner valued network customer selected receivea  prize reward claim  claim code  valid hours only mobile months more u r entitled update latest colour mobiles camera free mobile update co free im gonna home soon want talk stuff anymore tonight k ive cried today chances win cash  pounds txt send  cost day   tsandcs apply reply hl info urgent week free membership  prize jackpot txt word claim no tc wwwdbuknet lccltd pobox ive searching right words thank breather promise wont help granted fulfil promise wo
# ...

# %%
s = nfx.clean_text(s)  

# Birleştirilmiş metni temizler; özel karakterler, sayılar ve gereksiz boşlukları kaldırır

# %%
s = nfx.remove_special_characters(s)  

# Metindeki özel karakterleri kaldırır; yalnızca harf ve sayıları bırakır

# %%
s  

# Temizlenmiş ve özel karakterlerden arındırılmış birleşik metni görüntüler
# Out:
# 'jurong point crazy available bugis n great world la e buffet cine got amore wat ok lar joking wif u oni free entry wkly comp win fa cup final tkts text fa receive entry questionstd txt ratetcs apply u dun early hor u c nah think goes usf lives freemsg hey darling weeks word id like fun tb ok xxx std chgs send rcv brother like speak treat like aids patent request melle melle oru minnaminunginte nurungu vettam set callertune callers press copy friends callertune winner valued network customer selected receivea prize reward claim claim code valid hours mobile months u r entitled update latest colour mobiles camera free mobile update co free im gonna home soon want talk stuff anymore tonight k ive cried today chances win cash pounds txt send cost day tsandcs apply reply hl info urgent week free membership prize jackpot txt word claim tc wwwdbuknet lccltd pobox ive searching right words thank breather promise wont help granted fulfil promise wonderful blessing times date sunday xxxmobile
# ...

# %%
s = nfx.TextFrame(s)  

# Metni neattext’in TextFrame objesine dönüştürür; metin analizi ve istatistikleri için kullanılabilir

# %% [markdown]
# #### _Exploratory Data Analysis on Cleaned Text Data_

# %%
s.describe()  

# TextFrame içindeki metinle ilgili istatistikleri özetler; kelime sayısı, karakter sayısı gibi bilgiler verir
# Out:
# Key      Value
# Length  : 251679
# vowels  : 74710
# consonants: 134267
# stopwords: 0
# punctuations: 0
# special_char: 0
# tokens(whitespace): 42703
# tokens(words): 42703

# %%
s.length  

# TextFrame içindeki toplam karakter sayısını verir
# Out:
# 251679

# %%
s.head()  

# TextFrame içindeki ilk birkaç satırı veya metin örneklerini görüntüler
# Out:
# 'juron'

# %%
s.tail()  

# TextFrame içindeki son birkaç satırı veya metin örneklerini görüntüler
# Out:
# ' true'

# %%
s.readability()  

# TextFrame içindeki metinlerin okunabilirlik skorunu hesaplar
# (örneğin Flesch Reading Ease veya benzeri metrikler)
# Out:
# {'automated readability': 21357.829363276585, 'description': None}

# %% [markdown]
# #### _Seaborn_

# %%
import seaborn as sns  

# Veri görselleştirme için seaborn kütüphanesini içe aktarır

# %%
sns.countplot(x=df['class']);  

# Spam veri setindeki sınıf dağılımını görselleştirir
# 'ham' ve 'spam' mesajların sayısını karşılaştırmak için kullanılır

# %% [markdown]
# #### _Data Imblanced_

# %% [markdown]
# _Data Imbalance, bir veri setindeki sınıfların sayıca eşit olmaması durumudur. Özellikle sınıflandırma problemlerinde, bir sınıfa ait örneklerin diğerine göre çok daha fazla olması model performansını olumsuz etkileyebilir. Örneğin, SMS spam tespitinde gerçek (ham) mesajlar genellikle spam mesajlara kıyasla daha fazladır._

# %%
from imblearn.over_sampling import SMOTE  

# Dengesiz veri setlerinde azınlık sınıfını çoğaltarak denge sağlamak için SMOTE algoritmasını içe aktarır

# %%
x = df['text']  
# Modelin girdi (features) verisi olarak metin sütununu alır

y = df['class']  
# Modelin hedef (target) verisi olarak sınıf sütununu alır (ham/spam)

# %%
# smote = SMOTE(random_state=42)  
# x_resample, y_resample = smote.fit_resample(x, y)  

# Dengesiz sınıf dağılımını dengelemek için SMOTE uygulanabilir
# Ancak metin verisi doğrudan SMOTE ile çoğaltılamaz; önce sayısal vektörlere dönüştürülmelidir

# %% [markdown]
# #### _Using Pipeline for Data Processing and Modeling_

# %%
from sklearn.feature_extraction.text import CountVectorizer  

# Metinleri sayısal vektörlere dönüştürmek için CountVectorizer sınıfını içe aktarır

# %%
from sklearn.ensemble import RandomForestClassifier  

# Random Forest sınıflandırma modelini içe aktarır; birden fazla karar ağacını birleştirerek güçlü bir tahmin modeli oluşturur

# %%
from sklearn.pipeline import Pipeline  

# Veri işleme ve model adımlarını ardışık bir şekilde birleştirmek için Pipeline sınıfını içe aktarır

# %%
clf = Pipeline([
    ('CountVect', CountVectorizer()),
    ('Classifier', RandomForestClassifier())
])  

# Pipeline ile metin verisini önce CountVectorizer ile vektörleştirir, ardından Random Forest sınıflandırıcı ile tahmin yapar

# %%
from sklearn.model_selection import train_test_split  

# Veriyi eğitim ve test setlerine ayırmak için gerekli fonksiyonu içe aktarır

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)  

# Veriyi %80 eğitim ve %20 test olarak ayırır; random_state ile tekrar üretilebilirlik sağlanır

# %%
clf.fit(x_train, y_train)  

# Pipeline içindeki CountVectorizer ve Random Forest modelini eğitim verisi ile birlikte eğitir
# Out:
# Pipeline(steps=[('CountVect', CountVectorizer()),
#                 ('Classifier', RandomForestClassifier())])

# %%
tahmin = clf.predict(x_test)  

# Eğitilmiş model ile test verisinin sınıflarını tahmin eder

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix  

# Model performansını değerlendirmek için gerekli metrikleri ve karışıklık matrisini içe aktarır

# %%
accuracy_score(y_test, tahmin)  

# Modelin test verisi üzerindeki doğruluk (accuracy) oranını hesaplar
# Out:
# 0.9713004484304932

# %%
print(classification_report(y_test, tahmin))  

# Modelin test verisi üzerindeki sınıf bazlı performansını gösterir
# Precision, Recall, F1-score ve destek (support) değerlerini içerir
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98       965
#         spam       0.99      0.79      0.88       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.90      0.93      1115
# weighted avg       0.97      0.97      0.97      1115

# %%
confusion_matrix(tahmin, y_test)  

# Tahminler ile gerçek değerler arasındaki karışıklık matrisini hesaplar
# Hangi sınıfların doğru/yanlış tahmin edildiğini gösterir
# Out:
# array([[964,  31],
#        [  1, 119]])

# %%
from sklearn.svm import SVC  

# Destek Vektör Makinesi (Support Vector Classifier) sınıflandırıcı modelini içe aktarır

# %%
svm = Pipeline([
    ('CountVect', CountVectorizer()),
    ('Classifier', SVC())
])  

# Pipeline oluşturur: metni önce CountVectorizer ile vektörleştirir, ardından Support Vector Classifier ile sınıflandırır

# %%
svm.fit(x_train, y_train)  

# Pipeline içindeki CountVectorizer ve Random Forest modelini eğitim verisi ile birlikte eğitir
# Out:
# Pipeline(steps=[('CountVect', CountVectorizer()), ('Classifier', SVC())])

# %%
tahmin2 = svm.predict(x_test)  

# Eğitilmiş model ile test verisinin sınıflarını tahmin eder

# %%
accuracy_score(y_test, tahmin2)  

# İkinci modelin (svm pipeline) test verisi üzerindeki doğruluk (accuracy) oranını hesaplar
# Out:
# 0.9748878923766816

# %%
print(classification_report(y_test, tahmin2))  

# İkinci modelin test verisi üzerindeki sınıf bazlı performansını gösterir
# Precision, Recall, F1-score ve destek (support) değerlerini içerir
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99       965
#         spam       0.99      0.82      0.90       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.91      0.94      1115
# weighted avg       0.98      0.97      0.97      1115

# %%
confusion_matrix(tahmin2, y_test)  

# İkinci modelin tahminleri ile gerçek değerler arasındaki karışıklık matrisini hesaplar
# Hangi sınıfların doğru/yanlış tahmin edildiğini gösterir
# Out:
# array([[964,  27],
#        [  1, 123]])

# %%
sns.heatmap(confusion_matrix(tahmin2, y_test), annot=True);  

# İkinci modelin karışıklık matrisini görselleştirir
# Annot=True ile hücre değerlerini gösterir

# %% [markdown]
# #### _Testing the Model with Sample SMS Messages_

# %%
test1 = ['Hello you are learning Natural Language Processing']  
test2 = ['Congratulations! you won a lottery ticket. to claim call 1-800-899-999']  
test3 = ['free entry wkly comp win fa cup final tkts']  

# Üç örnek metin tanımlar:
# test1 → normal mesaj
# test2 → potansiyel spam mesajı
# test3 → kısa ve tipik spam mesajı

# %%
clf.predict(test1)  

# Eğitilmiş model ile test1 mesajının sınıfını tahmin eder
# Çıkış: 'ham' (normal mesaj) veya 'spam'
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(test2)

# Model test2 verisiyle tahmin üretir
# Out:
# array(['spam'], dtype=object)

# %%
clf.predict(test3)

# Model test3 verisiyle tahmin üretir
# Out:
# array(['spam'], dtype=object)

# %%
svm.predict(test1)

# SVM modeli test1 verisi için tahmin üretir
# Out:
# array(['ham'], dtype=object)

# %%
svm.predict(test2)

# SVM modeli test2 verisi için tahmin üretir
# Out:
# array(['spam'], dtype=object)

# %%
svm.predict(test3)

# SVM modeli test3 verisi için tahmin üretir
# Out:
# array(['spam'], dtype=object)

# %% [markdown]
# #### _Using Joblib for Model Persistence_

# %%
import joblib

# joblib kütüphanesini projeye dahil eder

# %%
joblib.dump(svm,'svm_hs.pkl')

# SVM modelini svm_hs.pkl dosyasına kaydeder
# Out:
# ['svm_hs.pkl']

# %%
joblib.dump(clf,'clf_hs.pkl')

# clf modelini clf_hs.pkl dosyasına kaydeder
# Out:
# ['clf_hs.pkl']

# %%
loaded_model = joblib.load('svm_hs.pkl')

# svm_hs.pkl dosyasındaki modeli yükler

# %%
loaded_model.predict(test2)

# Yüklenen model test2 verisiyle tahmin yapar
# Out:
# array(['spam'], dtype=object)

# %% [markdown]
# #### _Creating a Word Cloud Function_

# %%
#pip install wordcloud

# %%
# wordcloud kütüphanesini yüklemek için gerekli komut

# %%
from wordcloud import WordCloud
# WordCloud sınıfını projeye dahil eder

from wordcloud import STOPWORDS
# WordCloud için durdurma kelimelerini içe aktarır

import numpy as np
# Sayısal işlemler için numpy kütüphanesini dahil eder

import matplotlib.pyplot as plt
# Grafik ve görselleştirme işlemleri için matplotlib ekler

from PIL import Image
# Görüntü işleme işlemleri için PIL.Image modülünü içe aktarır

# %%
def wc(data,color):
    # Kelime bulutu fonksiyonunu tanımlar

    plt.figure(figsize=(10,10))
    # Grafik boyutunu ayarlar

    wc=WordCloud(background_color=color, stopwords=STOPWORDS)
    # WordCloud nesnesini verilen arka plan ve stopwords ile oluşturur

    wc.generate(' '.join(data))
    # Data liste elemanlarını birleştirerek kelime bulutu üretir

    plt.imshow(wc)
    # Kelime bulutunu görüntüler

    plt.axis('off')
    # Grafik eksenlerini gizler

# %%
spam = df[df['class']=='spam']
# class sütunu spam olan verileri seçer

ham = df[df['class']=='ham']
# class sütunu ham olan verileri seçer

# %%
spam.head()

# spam verilerinin ilk birkaç satırını gösterir
# Out:
#    class                                               text
# 2   spam  free entry wkly comp win fa cup final tkts  te...
# 5   spam  freemsg hey darling weeks word back id like fu...
# 8   spam  winner valued network customer selected receiv...
# 9   spam  mobile months more u r entitled update latest ...
# 11  spam  chances win cash  pounds txt send  cost day   ...

# %%
wc(ham['text'],'white')

# ham mesajlarının kelime bulutunu beyaz arka planla oluşturur

# %%
wc(spam['text'],'red')

# spam mesajlarının kelime bulutunu kırmızı arka planla oluşturur

# %%
def wc(data,color):
    # Kelime bulutu fonksiyonunu tanımlar

    plt.figure(figsize=(10,10))
    # Grafik boyutunu 10x10 olacak şekilde ayarlar

    mask = np.array(Image.open('cloud.png'))
    # cloud.png görselini maske olarak yükler

    wc = WordCloud(background_color=color, stopwords=STOPWORDS, mask=mask)
    # Arka plan rengi, stopwords ve mask parametreleri ile WordCloud oluşturur

    wc.generate(' '.join(data))
    # Data’daki metinleri birleştirerek kelime bulutu üretir

    plt.imshow(wc)
    # Oluşturulan kelime bulutunu ekrana çizer

    plt.axis('off')
    # Grafik eksenlerini kapatarak sade görünüm sağlar

# %%
wc(ham['text'],'white')

# ham mesajları için beyaz arka planlı kelime bulutu oluşturur

# %% [markdown]
# #### _Sentiment Analysis_

# %%
test1 = 'I love hard work, dedication, and reading'
# test1 değişkenine pozitif içerikli bir metin atanır

test2 = 'I hate you'
# test2 değişkenine olumsuz içerikli bir metin atanır

test3 = 'climate change is real'
# test3 değişkenine iklim değişikliği ile ilgili bir metin atanır

# %%
from textblob import TextBlob

# TextBlob kütüphanesindeki sınıfı projeye dahil eder

# %%
blob = TextBlob(test3)

# test3 metninden bir TextBlob nesnesi oluşturur

# %%
blob.sentiment

# metnin duygu analizini (polarity ve subjectivity) hesaplar
# Out:
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004)

# %%
blob.sentiment.polarity

# metnin duygu değerini sayı olarak döndürür
# Out:
# 0.2

# %%
blob.sentiment.subjectivity

# metnin öznelik derecesini döndürür
# Out:
# 0.30000000000000004

# %% [markdown]
# #### _Sentiment Analysis Using Pretrained Transformer Models_

# %%
#pip install transformers

# %%
# transformers kütüphanesini yüklemek için gerekli pip komutu

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
# Gerekli transformer bileşenlerini içe aktarır

model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
# Türkçe duygu analizi için önceden eğitilmiş BERT modelini yükler

tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
# Aynı model için tokenizer yüklenir

sa = pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)
# Duygu analizi pipeline’ı tokenizer ve model ile başlatılır

p = sa("bu telefon modelleri çok kaliteli , her parçası çok özel bence")
# Verilen Türkçe metin için duygu tahmini yapılır

print(p)
# Tahmin sonucu ekrana yazdırılır
# [{'label': 'LABEL_1', 'score': 0.9871089)]
# Örnek çıktı modelin pozitif sınıf tahminini gösterir (LABEL_1)

print(p[0]['label'] == 'LABEL_1')
# Tahmin edilen etiket pozitif mi kontrol eder
# True
# Pozitif sınıfa ait olduğu için sonuç True olacaktır

p = sa("Film çok kötü ve çok sahteydi")
# Olumsuz içerikli bir metin için duygu tahmini yapılır

print(p)
# Tahmin sonucu ekrana yazdırılır
# [{'label': 'LABEL_0', 'score': 0.9975505}]
# Modelin negatif tahmin yaptığını örnek çıktı gösterir

print(p[0]['label'] == 'LABEL_1')
# Tahmin edilen etiket pozitif mi kontrol eder

# False
# Negatif olduğu için sonuç False olur
# Out:
# Device set to use cpu
# [{'label': 'positive', 'score': 0.983146607875824}]
# False
# [{'label': 'negative', 'score': 0.9990053772926331}]
# False

# %% [markdown]
# _Bu projede, doğal dil işleme (NLP) ve makine öğrenmesi teknikleri kullanılarak metin verilerinin etkili bir şekilde analiz edilebileceği gösterilmiştir. Metin temizleme ve ön işleme adımlarından başlayarak keşifsel veri analizi (EDA), modelleme, değerlendirme ve örnek metinler üzerinde yapılan testler ile uçtan uca bir duygu analizi ve spam tespit süreci başarıyla gerçekleştirilmiştir. Elde edilen sonuçlar, doğru veri hazırlama ve uygun model seçiminin metin tabanlı problemlerde model performansını doğrudan etkilediğini ortaya koymaktadır._
