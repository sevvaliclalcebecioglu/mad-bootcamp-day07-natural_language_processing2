# %% [markdown]
# # _Naturel Language Processing 2 - Ham or Spam_

# %% [markdown]
# _Bugün bir GSM şirketine makine öğrenmesi modeli geliştirip gönderilen text mesajların gerçek mesaj mı yoksa spam reklam mı olduğunu anlayan bir model geliştireceğiz._

# %%
#pip install neattext

# %%
import neattext as nfx

# %%
s=open('test_document.txt','r',encoding='utf-8').read()

# %%
s
# Out:
# '\nDear User! 😊🎉\n\nWe are <b>excited</b> to inform you that your registration is complete! 🔥🔥🔥\nEncounter issues❓ Contact: support@example.com 👍\n\nFor marketing, inquiries📢 reach out: marketing@sample.org or sales-team@business123.com💼\n\n‼️ PLEASE NOTE: Do not reply to no-reply@mailer.system.net 📵 (Unmonitored)\n\nForgot your password❓❗️ Email: password.reset@securemail.co.uk 🔐\n\nThank you 🙏 for your cooperation!\n\nBest Regards,\nAdmin Team 🖥️\nadmin.team@mywebsite.com\n\n## User Feedback 💡\n\nWe value your feedback! Share your experiences 🌟 at feedback@customer-reviews.io 📧\n\nTechnical assistance: email tech-support@techsolutions.net or 📞 our helpline.\n\n### Random User Information 📝:\n\n- John Doe: john.doe123@examplemail.com 🧑\u200d💻\n- Jane Smith: jane.smith987@randommail.org 👩\u200d🔬\n- Alice Brown: alice_brown@abc-company.co 👩\u200d💼\n\n### Internal Contacts 📂:\n\n- CEO Office 🏢: ceo.office@company-exec.com\n- HR Department 🧑\u200d🤝\u200d🧑: hr.department@corporate-group.
# ...

# %%
nfx.extract_emails(s)
# Out:
# ['support@example.com',
#  'marketing@sample.org',
#  'sales-team@business123.com',
#  'no-reply@mailer.system.net',
#  'password.reset@securemail.co.uk',
#  'admin.team@mywebsite.com',
#  'feedback@customer-reviews.io',
#  'tech-support@techsolutions.net',
#  'john.doe123@examplemail.com',
#  'jane.smith987@randommail.org',
#  'alice_brown@abc-company.co',
#  'ceo.office@company-exec.com',
#  'hr.department@corporate-group.com',
#  'it_helpdesk@it-support.biz',
#  'info@canada-office.ca',
#  'support.au@serviceprovider.com.au',
#  'kontakt@firma-beispiel.de',
#  'serviceclient@exemple.fr',
#  '技術サポート@例え.jp',
#  'informacion@empresa.es',
#  'vendas@empresa.com.br',
#  'запросы@пример.рф',
#  '咨询@公司.cn',
#  'seva@bharat.co.in']

# %%
s = nfx.remove_emails(s)

# %%
s
# Out:
# '\nDear User! 😊🎉\n\nWe are <b>excited</b> to inform you that your registration is complete! 🔥🔥🔥\nEncounter issues❓ Contact:  👍\n\nFor marketing, inquiries📢 reach out:  or 💼\n\n‼️ PLEASE NOTE: Do not reply to  📵 (Unmonitored)\n\nForgot your password❓❗️ Email:  🔐\n\nThank you 🙏 for your cooperation!\n\nBest Regards,\nAdmin Team 🖥️\n\n\n## User Feedback 💡\n\nWe value your feedback! Share your experiences 🌟 at  📧\n\nTechnical assistance: email  or 📞 our helpline.\n\n### Random User Information 📝:\n\n- John Doe:  🧑\u200d💻\n- Jane Smith:  👩\u200d🔬\n- Alice Brown:  👩\u200d💼\n\n### Internal Contacts 📂:\n\n- CEO Office 🏢: \n- HR Department 🧑\u200d🤝\u200d🧑: \n- IT Helpdesk 🛠️: \n\n### International Contacts 🌐:\n\n- Canada Office 🍁: \n- Australia Support 🇦🇺: \n- Germany Team 🇩🇪: \n- France Customer Service 🇫🇷: \n- Japan Technical Support 🇯🇵: \n- Spain Info 🇪🇸: \n- Brazil Sales 🇧🇷: \n- Russia Queries 🇷🇺: \n- China Inquiries 🇨🇳: \n- India Services 🇮🇳: \n\nSome random HTML code:\n<div class="foote
# ...

# %%
s = nfx.remove_emojis(s)

# %%
s = nfx.remove_special_characters(s)

# %%
s
# Out:
# 'Dear User We are bexcitedb to inform you that your registration is complete Encounter issues Contact  For marketing inquiries reach out  or  PLEASE NOTE Do not reply to   UnmonitoredForgot your password Email  Thank you  for your cooperationBest RegardsAdmin Team  User Feedback We value your feedback Share your experiences  at  Technical assistance email  or  our helpline Random User Information  John Doe   Jane Smith   Alice Brown   Internal Contacts  CEO Office   HR Department   IT Helpdesk   International Contacts  Canada Office   Australia Support   Germany Team   France Customer Service   Japan Technical Support   Spain Info   Brazil Sales   Russia Queries   China Inquiries   India Services  Some random HTML codediv classfooter2025 a hrefhttpsexamplecomExample Corpa All rights reserveddivscriptalertThis is a test alert script Historical Quotes  To be or not to be that is the question  William Shakespeare  I think therefore I am  Ren Descartes  Thats one small step for man one g
# ...

# %%
s = nfx.normalize(s)

# %%
s
# Out:
# 'dear user we are bexcitedb to inform you that your registration is complete encounter issues contact  for marketing inquiries reach out  or  please note do not reply to   unmonitoredforgot your password email  thank you  for your cooperationbest regardsadmin team  user feedback we value your feedback share your experiences  at  technical assistance email  or  our helpline random user information  john doe   jane smith   alice brown   internal contacts  ceo office   hr department   it helpdesk   international contacts  canada office   australia support   germany team   france customer service   japan technical support   spain info   brazil sales   russia queries   china inquiries   india services  some random html codediv  a hrefhttpsexamplecomexample corpa all rights reserveddivscriptalertthis is a test alert script historical quotes  to be or not to be that is the question  william shakespeare  i think therefore i am  ren descartes  thats one small step for man one giant leap for m
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('spam.csv', encoding='iso-8859-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# veya df=df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1) birden fazla sutun silme

# %%
df=df[['v1','v2']]

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns=['class', 'text'] # sutun isimlerini degistirme

# %%
df.head()
# Out:
#   class                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import neattext as nfx

# %%
df['text']=df['text'].apply(nfx.normalize)

# %%
df.text
# Out:
# 0       go until jurong point, crazy.. available only ...
# 1                           ok lar... joking wif u oni...
# 2       free entry in  a wkly comp to win fa cup final...
# 3       u dun say so early hor... u c already then say...
# 4       nah i don't think he goes to usf, he lives aro...
#                               ...
# 5567    this is the  time we have tried  contact u. u ...
# 5568                will ì_ b going to esplanade fr home?
# 5569    pity, * was in mood for that. so...any other s...
# 5570    the guy did some bitching but i acted like i'd...
# 5571                           rofl. its true to its name
# Name: text, Length: 5572, dtype: object

# %%
df['text']=df['text'].apply(nfx.clean_text)

# %%
df['text']=df['text'].apply(nfx.remove_special_characters)

# %%
s=' '.join(df['text'])

# %%
s=nfx.TextFrame(s)

# %%
s.describe()
# Out:
# Key      Value
# Length  : 264939
# vowels  : 78234
# consonants: 139054
# stopwords: 2471
# punctuations: 0
# special_char: 0
# tokens(whitespace): 45174
# tokens(words): 45174

# %%
s.length
# Out:
# 264939

# %%
s.vowels
# Out:
# {'a': 16178, 'e': 24337, 'i': 14701, 'o': 15885, 'u': 7133}

# %%
s.head(100)
# Out:
# 'jurong point crazy available bugis n great world la e buffet cine got amore wat ok lar joking wif u '

# %%
s.tail(100)
# Out:
# 'y  mood that soany suggestions guy bitching acted like id interested buying week gave free rofl true'

# %%
s.readability()
# Out:
# {'automated readability': 23830.7569950894, 'description': None}

# %%
import nltk

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\13tua\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
seyhpir = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')

# %%
seyhpir
# Out:
# "[The Tragedie of Hamlet by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Barnardo and Francisco two Centinels.\n\n  Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe\n\n   Bar. Long liue the King\n\n   Fran. Barnardo?\n  Bar. He\n\n   Fran. You come most carefully vpon your houre\n\n   Bar. 'Tis now strook twelue, get thee to bed Francisco\n\n   Fran. For this releefe much thankes: 'Tis bitter cold,\nAnd I am sicke at heart\n\n   Barn. Haue you had quiet Guard?\n  Fran. Not a Mouse stirring\n\n   Barn. Well, goodnight. If you do meet Horatio and\nMarcellus, the Riuals of my Watch, bid them make hast.\nEnter Horatio and Marcellus.\n\n  Fran. I thinke I heare them. Stand: who's there?\n  Hor. Friends to this ground\n\n   Mar. And Leige-men to the Dane\n\n   Fran. Giue you good night\n\n   Mar. O farwel honest Soldier, who hath relieu'd you?\n  Fra. Barnardo ha's my place: giue you goodnight.\n\nExit Fran.\n\n  Mar. Holla Barnardo\n\n   Bar
# ...

# %%
seyhpir = nfx.TextFrame(seyhpir)

# %%
seyhpir.describe()
# Out:
# Key      Value
# Length  : 162881
# vowels  : 48344
# consonants: 73960
# stopwords: 13996
# punctuations: 7093
# special_char: 7093
# tokens(whitespace): 29605
# tokens(words): 30273

# %%
seyhpir.readability()
# Out:
# {'automated readability': 12.990613823318782,
#  'description': '18-24 years (College student)'}

# %%
import seaborn as sns

# %%
sns.countplot(x=df['class']);

# %%
d={'spam':1,'ham':0}

# %%
df['label']=df['class'].map(d)

# %%
df.head()
# Out:
#   class                                               text  label
# 0   ham  jurong point crazy available bugis n great wor...      0
# 1   ham                            ok lar joking wif u oni      0
# 2  spam  free entry wkly comp win fa cup final tkts  te...      1
# 3   ham                            u dun early hor u c say      0
# 4   ham                           nah think goes usf lives      0

# %%
x=df['text']
y=df['label']

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline # verinin boyutunun aynı kalması ve islem sirasini yeni datayada uygulamak icin kullanılır.

# %%
clf=Pipeline([('CountVect', CountVectorizer(ngram_range=(1,2))), ('Classifier', RandomForestClassifier())])

# %%
# yukardaki satır ile boyut uyuşmazlığını ortadan kaldırmış oluyoruz.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('CountVect', CountVectorizer(ngram_range=(1, 2))),
#                 ('Classifier', RandomForestClassifier())])

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
pred=clf.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9650224215246637

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[965,   0],
#        [ 39, 111]])

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       965
#            1       1.00      0.74      0.85       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.87      0.92      1115
# weighted avg       0.97      0.97      0.96      1115

# %%
from sklearn.svm import SVC

# %%
clf2=Pipeline([('CountVect', CountVectorizer(ngram_range=(1,2))), ('Classifier', SVC())])

# %%
clf2.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('CountVect', CountVectorizer(ngram_range=(1, 2))),
#                 ('Classifier', SVC())])

# %%
pred2=clf2.predict(x_test)

# %%
accuracy_score(y_test, pred2)
# Out:
# 0.9730941704035875

# %%
confusion_matrix(y_test, pred2)
# Out:
# array([[964,   1],
#        [ 29, 121]])

# %%
print(classification_report(y_test, pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       965
#            1       0.99      0.81      0.89       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.90      0.94      1115
# weighted avg       0.97      0.97      0.97      1115

# %%
text1=['Hello, how are you? You are learning Natural Language Processing']
text2=['Congratulations! You won a lottary ticket. to claim call 1-800-888-3365']
text3=['free entry to world cups']

# %%
clf.predict(text1)
# Out:
# array([0])

# %%
import joblib

# %%
joblib.dump(clf,'rf_hsc.pkl ')
# Out:
# ['rf_hsc.pkl ']

# %%
# örnek cümle alalım;

# %%
df[df['class']=='spam']['text']
# Out:
# 2       free entry wkly comp win fa cup final tkts  te...
# 5       freemsg hey darling weeks word back id like fu...
# 8       winner valued network customer selected receiv...
# 9       mobile months more u r entitled update latest ...
# 11      chances win cash  pounds txt send  cost day   ...
#                               ...
# 5537    want explicit sex secs ring now costs min gsex...
# 5540    asked chatlines inclu free mins india cust ser...
# 5547    contract mobile mnths latest motorola nokia et...
# 5566    reminder   pounds free credit details great of...
# 5567    time tried contact u u  pound prize claim easy...
# Name: text, Length: 747, dtype: object

# %%
#pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# aynı kodu 2 kez yazmamak için def (fonksiyon) tanımlıyoruz

# %%
def wc(data, color):
    plt.figure(figsize=(10,10))
    wc=WordCloud(background_color=color, stopwords=STOPWORDS)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
spam=df[df['class']=='spam']
ham=df[df['class']=='ham']

# %%
wc(ham['text'],'white')

# %%
wc(spam['text'],'red')

# %%
def wc(data, color):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open('cloud.png'))
    wc=WordCloud(background_color=color, stopwords=STOPWORDS, mask=mask)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
wc(ham['text'],'white')

# %%
wc(spam['text'],'white')

# %% [markdown]
# # _Sentiment Analysis_

# %%
t1='I love hard work, dedication and commitment'
t2='you are the worst person ever'
t3='you are the best'
t4='Climate change is real'

# %%
from textblob import TextBlob

# %%
blob = TextBlob(t1)

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.10416666666666666, subjectivity=0.5708333333333333)

# %%
blob.sentiment.polarity
# Out:
# 0.10416666666666666

# %%
blob.sentiment.subjectivity
# Out:
# 0.5708333333333333

# %%
#pip install transformers

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
sa= pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)

p = sa("bu telefon modelleri çok kaliteli , her parçası çok özel bence")
print(p)
# [{'label': 'LABEL_1', 'score': 0.9871089}]
print(p[0]['label'] == 'LABEL_1')
# True

p = sa("Film çok kötü ve çok sahteydi")
print(p)
# [{'label': 'LABEL_0', 'score': 0.9975505}]
print(p[0]['label'] == 'LABEL_1')
# False
# Out:
# Device set to use cpu
# [{'label': 'positive', 'score': 0.983146607875824}]
# False
# [{'label': 'negative', 'score': 0.9990053772926331}]
# False
